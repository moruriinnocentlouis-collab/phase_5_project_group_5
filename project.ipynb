# %% [markdown]
# LOADING AND MERGIND THE 9 FILES

# %%
import pandas as pd

# %%
good_faith = pd.read_csv("Good Faithh.csv")
good_faith
# Out:
#                  Account Name  2019  2020           2021           2022  \
# 0                Total Assets     0     0  66,045,912.00  74,532,015.25
# 1   Total Deposit liabilities     0     0  47,580,831.00  51,641,674.00
# 2                Total Equity     0     0  15,603,894.00  19,350,690.00
# 3           Total Liabilities     0     0  50,442,019.00  55,181,326.00
# 4      Cash & Cash Equivalent     0     0  19,799,397.00  20,884,959.00
# 5       Financial Investments     0     0      25,330.00      24,550.00
# 6        Gross Loan Portfolio     0     0  47,572,950.00  52,516,192.00
# 7          Net Loan Portfolio     0     0  37,252,147.00  44,088,836.25
# 8      Current Year's Surplus     0     0              0              0
# 9               Share Capital     0     0  10,271,434.00  10,720,832.00
# 10          Statutory Reserve     0     0              0   4,030,156.00
#
#              2023
# 0   78,895,301.12
# 1   56,120,443.00
# 2   19,842,551.00
# 3   59,052,750.12
# ...

# %%
good_way = pd.read_csv("Goodwayy Sacco.csv")
good_way
# Out:
#                  Account Name        2019        2020        2021        2022  \
# 0                Total Assets  45,621,444  49,793,828  56,660,235  60,579,585
# 1   Total Deposit liabilities  19,185,646  23,669,977  30,511,071  28,679,000
# 2                Total Equity  21,784,320  23,142,108  23,368,609  23,404,025
# 3           Total Liabilities  23,837,124  26,651,721  34,068,710  36,872,613
# 4      Cash & Cash Equivalent   5,913,431   8,460,800   7,528,330   3,906,758
# 5       Financial Investments     914,790   1,121,325   1,811,583   1,825,751
# 6        Gross Loan Portfolio  35,170,961  35,483,959  38,088,372  44,270,076
# 7          Net Loan Portfolio  34,556,455  34,818,647  37,148,812  43,353,686
# 8      Current Year's Surplus   2,763,822   1,306,803     853,669   1,171,271
# 9               Share Capital  11,986,229  11,986,229  11,986,229  13,324,579
# 10          Statutory Reserve   2,552,633   2,934,091   3,104,825   3,404,384
#
#          2023*
# 0   47,562,451
# ...

# %%
hazina = pd.read_csv("Hazina Accounts.csv")
hazina
# Out:
#                  Account Name           2019           2020            2021  \
# 0                Total Assets  8,432,323,283  9,144,307,882  10,470,223,736
# 1   Total Deposit Liabilities  6,290,093,029  6,864,888,284   7,935,970,950
# 2                Total Equity  1,847,566,350  2,050,421,795   2,342,752,943
# 3           Total Liabilities  6,584,756,933  7,093,886,087   8,127,470,793
# 4      Cash & Cash Equivalent    448,510,967    640,432,593   1,223,803,506
# 5       Financial Investments    205,372,217    129,569,217     254,495,353
# 6        Gross Loan Portfolio  7,267,006,204  7,725,650,490   8,368,098,735
# 7          Net Loan Portfolio  7,126,202,308  7,575,178,217   8,205,091,894
# 8      Current Year's Surplus    805,102,590    838,620,016     986,508,610
# 9               Share Capital    506,009,469    572,267,522     682,755,758
# 10          Statutory Reserve    329,481,214    363,225,214     402,945,558
#
#               2022            2023
# ...

# %%
home_business = pd.read_csv("Home business accounts approval .csv")
home_business
# Out:
#                  Account Name           2019           2020            2021  \
# 0                Total Assets  8,432,323,283  9,144,307,882  10,470,223,736
# 1   Total Deposit Liabilities  6,290,093,029  6,864,888,284   7,935,970,950
# 2                Total Equity  1,847,566,350  2,050,421,795   2,342,752,943
# 3           Total Liabilities  6,584,756,933  7,093,886,087   8,127,470,793
# 4      Cash & Cash Equivalent    448,510,967    640,432,593   1,223,803,506
# 5       Financial Investments    205,372,217    129,569,217     254,495,353
# 6        Gross Loan Portfolio  7,267,006,204  7,725,650,490   8,368,098,735
# 7          Net Loan Portfolio  7,126,202,308  7,575,178,217   8,205,091,894
# 8      Current Year's Surplus    805,102,590    838,620,016     986,508,610
# 9               Share Capital    506,009,469    572,267,522     682,755,758
# 10          Statutory Reserve    329,481,214    363,225,214     402,945,558
#
#               2022            2023
# ...

# %%
ig = pd.read_csv("Home business accounts approval .csv")
ig
# Out:
#                  Account Name           2019           2020            2021  \
# 0                Total Assets  8,432,323,283  9,144,307,882  10,470,223,736
# 1   Total Deposit Liabilities  6,290,093,029  6,864,888,284   7,935,970,950
# 2                Total Equity  1,847,566,350  2,050,421,795   2,342,752,943
# 3           Total Liabilities  6,584,756,933  7,093,886,087   8,127,470,793
# 4      Cash & Cash Equivalent    448,510,967    640,432,593   1,223,803,506
# 5       Financial Investments    205,372,217    129,569,217     254,495,353
# 6        Gross Loan Portfolio  7,267,006,204  7,725,650,490   8,368,098,735
# 7          Net Loan Portfolio  7,126,202,308  7,575,178,217   8,205,091,894
# 8      Current Year's Surplus    805,102,590    838,620,016     986,508,610
# 9               Share Capital    506,009,469    572,267,522     682,755,758
# 10          Statutory Reserve    329,481,214    363,225,214     402,945,558
#
#               2022            2023
# ...

# %%
imarika = pd.read_csv("Imarika Sacco.csv")
imarika
# Out:
#                  Account Name           2019           2020            2021  \
# 0                Total Assets  9,152,783,165  9,737,422,176  10,131,847,994
# 1   Total Deposit liabilities  6,523,104,882  7,102,455,102   7,650,895,221
# 2                Total Equity  1,489,522,114  1,852,595,720   2,287,004,974
# 3           Total Liabilities  7,663,261,051  7,884,826,456   7,844,843,020
# 4      Cash & Cash Equivalent     19,363,224    893,579,487     753,154,463
# 5       Financial Investments    412,550,000    455,120,000     495,220,000
# 6        Gross Loan Portfolio  7,416,940,385  8,138,168,521   8,754,220,110
# 7          Net Loan Portfolio  7,034,090,878  7,712,450,110   8,311,245,660
# 8      Current Year's Surplus    357,685,310    398,929,049     446,035,664
# 9               Share Capital    488,412,000    554,120,000     632,550,000
# 10          Statutory Reserve    312,450,000    385,120,000     452,110,000
#
#               2022            2023
# ...

# %%
jamii = pd.read_csv("Jamii.csv")
jamii
# Out:
#                  Account Name  2019           2020           2021  \
# 0                Total Assets     0  4,662,154,303  5,091,966,231
# 1   Total Deposit Liabilities     0  3,117,070,083  3,748,605,103
# 2                Total Equity     0  1,173,151,332  1,445,452,703
# 3           Total Liabilities     0  3,489,002,971  3,646,513,528
# 4      Cash & Cash Equivalent     0    371,352,866    462,253,410
# 5       Financial Investments     0    355,548,222    447,346,472
# 6        Gross Loan Portfolio     0  3,556,155,701  4,318,047,024
# 7          Net Loan Portfolio     0  3,248,349,650  3,063,015,547
# 8      Current Year's Surplus     0    462,063,290    117,708,139
# 9               Share Capital     0    446,959,264  1,091,106,575
# 10          Statutory Reserve     0    181,817,320    181,817,320
#
#              2022           2023
# 0   5,443,177,821  5,455,210,400
# 1   3,658,074,923  3,682,144,210
# 2   1,293,503,287  1,321,440,550
# 3   4,149,674,534  4,133,769,850
# ...

# %%
kenya_achievas = pd.read_csv("Kenya Achievas.csv")
kenya_achievas
# Out:
#                  Account Name            2019            2020            2021  \
# 0                Total Assets  412,300,818.84  392,978,893.46  390,333,250.97
# 1   Total Deposit liabilities  194,093,679.00  161,826,693.19  159,987,193.76
# 2                Total Equity  105,761,017.00  171,427,377.93  184,897,762.71
# 3           Total Liabilities  306,539,801.84  221,551,515.53  205,435,488.26
# 4      Cash & Cash Equivalent   70,985,223.00   38,341,912.77   28,993,165.31
# 5       Financial Investments   44,390,000.00   83,871,738.59   58,635,118.87
# 6        Gross Loan Portfolio  181,659,592.98  146,599,270.00  174,987,267.88
# 7          Net Loan Portfolio  174,526,543.00  119,582,723.61  148,161,380.41
# 8      Current Year's Surplus      487,234.00    5,367,586.27   11,401,373.05
# 9               Share Capital   37,090,876.00  118,844,476.36  125,122,050.09
# 10          Statutory Reserve   10,576,101.00    8,663,255.00    8,922,657.00
#
# ...

# %%
kenya_bankers = pd.read_csv("Kenya Bankers.csv")
kenya_bankers
# Out:
#                  Account Name           2019           2020           2021  \
# 0                Total Assets  8,021,456,200  9,103,337,522  9,103,337,522
# 1   Total Deposit liabilities  6,120,550,000  6,662,966,562  6,845,210,400
# 2                Total Equity    950,440,000  1,402,167,718  1,199,743,992
# 3           Total Liabilities  7,071,016,200  7,701,169,804  7,903,593,530
# 4      Cash & Cash Equivalent    150,200,000    195,018,007    136,268,767
# 5       Financial Investments     70,000,000     76,980,777     81,097,852
# 6        Gross Loan Portfolio  6,200,500,000  6,902,718,973  7,026,325,423
# 7          Net Loan Portfolio  5,800,400,000  6,454,710,541  6,747,324,365
# 8      Current Year's Surplus     65,000,000     88,400,500     94,210,300
# 9               Share Capital    420,500,000    468,993,626    472,219,391
# 10          Statutory Reserve    145,000,000    160,648,412    173,217,839
#
#              2022            2023
# ...

# %%
combined_df = pd.concat([good_faith, good_way, hazina, home_business, ig, imarika, jamii, kenya_achievas, kenya_bankers], axis=0)
combined_df
# Out:
#                  Account Name           2019           2020           2021  \
# 0                Total Assets              0              0  66,045,912.00
# 1   Total Deposit liabilities              0              0  47,580,831.00
# 2                Total Equity              0              0  15,603,894.00
# 3           Total Liabilities              0              0  50,442,019.00
# 4      Cash & Cash Equivalent              0              0  19,799,397.00
# ..                        ...            ...            ...            ...
# 6        Gross Loan Portfolio  6,200,500,000  6,902,718,973  7,026,325,423
# 7          Net Loan Portfolio  5,800,400,000  6,454,710,541  6,747,324,365
# 8      Current Year's Surplus     65,000,000     88,400,500     94,210,300
# 9               Share Capital    420,500,000    468,993,626    472,219,391
# 10          Statutory Reserve    145,000,000    160,648,412    173,217,839
#
#              2022           2023 2023*
# ...

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Account Name  99 non-null     object
#  1   2019          99 non-null     object
#  2   2020          99 non-null     object
#  3   2021          99 non-null     object
#  4   2022          99 non-null     object
#  5   2023          87 non-null     object
#  6   2023*         11 non-null     object
# dtypes: object(7)
# memory usage: 6.2+ KB
